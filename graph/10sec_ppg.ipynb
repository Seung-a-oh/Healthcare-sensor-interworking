# %% [markdown]
# # 10초 간의 PPG 센서 측정 값

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
load_data = np.loadtxt("10sec.csv", delimiter=',')

ppg = load_data[:,0]
beat = load_data[:,1]

plt.grid()
pli.plot(column, x_data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-704d8d36ab78> in <module>
# ----> 1 load_data = np.loadtxt("10sec.csv", delimiter=',')
#       2
#       3 ppg = load_data[:,0]
#       4 beat = load_data[:,1]
#       5
#
# ~\anaconda3\envs\v-world\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1146         # converting the data
#    1147         X = None
# -> 1148         for x in read_data(_loadtxt_chunksize):
#    1149             if X is None:
#    1150                 X = np.array(x, dtype)
#
# ~\anaconda3\envs\v-world\lib\site-packages\numpy\lib\npyio.py in read_data(chunk_size)
#     997
#     998             # Convert each value according to its column and store
# ...

# %%
df = pd.read_csv("10sec.csv")

df
# Out:
#         ppg    beat
# 0    0.3128  0.3128
# 1    0.6256  0.3128
# 2    1.2512  0.3128
# 3    0.9384  0.3128
# 4    0.9384  0.3128
# ..      ...     ...
# 195  0.6256  0.3128
# 196  0.6256  0.3128
# 197  0.9384  0.3128
# 198  0.9384  0.3128
# 199  0.6256  0.3128
#
# [200 rows x 2 columns]

# %%
time = list(np.arange(0,10,0.05))

df["time"] = time
df
# Out:
#         ppg    beat  time
# 0    0.3128  0.3128  0.00
# 1    0.6256  0.3128  0.05
# 2    1.2512  0.3128  0.10
# 3    0.9384  0.3128  0.15
# 4    0.9384  0.3128  0.20
# ..      ...     ...   ...
# 195  0.6256  0.3128  9.75
# 196  0.6256  0.3128  9.80
# 197  0.9384  0.3128  9.85
# 198  0.9384  0.3128  9.90
# 199  0.6256  0.3128  9.95
#
# [200 rows x 3 columns]

# %%
ppg = df.loc[:,'ppg']
beat = df.loc[:,'beat']
time = df.loc[:,'time']
# Out:
# 0      0.3128
# 1      0.6256
# 2      1.2512
# 3      0.9384
# 4      0.9384
#         ...
# 195    0.6256
# 196    0.6256
# 197    0.9384
# 198    0.9384
# 199    0.6256
# Name: ppg, Length: 200, dtype: float64
# 0      0.3128
# 1      0.3128
# 2      0.3128
# 3      0.3128
# 4      0.3128
#         ...
# 195    0.3128
# 196    0.3128
# 197    0.3128
# 198    0.3128
# 199    0.3128
# Name: beat, Length: 200, dtype: float64
# 0      0.00
# 1      0.05
# 2      0.10
# 3      0.15
# 4      0.20
#        ...
# 195    9.75
# 196    9.80
# 197    9.85
# 198    9.90
# 199    9.95
# Name: time, Length: 200, dtype: float64

# %%
plt.figure(figsize=(15,9))
plt.xlabel('sec',fontsize=20)
plt.ylabel('ppg value',fontsize=20)
plt.plot(time, ppg)

# %%
plt.figure(figsize=(15,9))
font = {
    'color':'deeppink',
    'size':20
}
plt.xlabel('sec',fontdict=font)
plt.ylabel('beat value', fontsize=20)
plt.plot(time, beat)
